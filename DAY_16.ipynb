# %%
stack=[]
n=int(input("Enter number of elements"))
for i in range(n):
    val=int(input("enter a value"))
    stack.append(val)
print("Stack : ",stack)
# Out:
# Enter number of elements 4
# enter a value 3
# enter a value 5
# enter a value 77
# enter a value 8
# Stack :  [3, 5, 77, 8]

# %%
stack=[]
size=int(input("Enter stack size:"))
n=int(input("Enter number of elements you want to push:"))
for i in range(n):
    if len(stack)<size:
        val=int(input("Enter value:"))
        stack.append(val)
    else:
        print("Stack over flow...")
while True:
    if len(stack)==0:
        print("Stack Empty....!")
        break
    else:
        print("popped:", stack.pop())
        print("Latest Stack", stack)
# Out:
# Enter stack size: 4
# Enter number of elements you want to push: 5
# Enter value: 22
# Enter value: 77
# Enter value: 989
# Enter value: 5
# Stack over flow...
# popped: 5
# Latest Stack [22, 77, 989]
# popped: 989
# Latest Stack [22, 77]
# popped: 77
# Latest Stack [22]
# popped: 22
# Latest Stack []
# Stack Empty....!

# %%
stack1=[]
stack2=[]
merged=[]
n1=int(input("enter number of elements in stack 1"))
for i in range(n1):
    val=int(input("enter value"))
    stack1.append(val)
n2=int(input("enter number of elements in stack 2"))
for i in range (n2):
    val=int(input("enter value"))
    stack2.append(val)
for i in range(len(stack1):
    print(stack1[i],end= ' ')
    print(stack2[i],end= ' ' )
print("Merged stack ",merged)
# Out:
#   Cell In[5], line 12
#     for i in range(len(stack1):
#                               ^
# SyntaxError: invalid syntax
