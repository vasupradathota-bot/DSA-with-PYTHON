# %%
#reverse an array 
n=int(input("Enter number of elements:"))
arr=[]
for i in range(n):
    val=int(input("Enter a value:"))
    arr.append(val)
print("Original array:")
for i in arr:
    print(i,end=" ")
print()
print("Reversed array:")
i=n-1
while i>=0:
    print(arr[i], end=' ')
    i-=1
# Out:
# Enter number of elements: 4
# Enter a value: 5
# Enter a value: 5
# Enter a value: 5
# Enter a value: 6
# Original array:
# 5 5 5 6
# Reversed array:
# 6 5 5 5

# %%
#code to rotate an array to left
n= int(input("Enter number of elements:"))
arr=[]
for i in range(n):
    val = int(input("Enter a value:"))
    arr.append(val)
print("Original array:")
for i in arr:
    print(i,end=" ")
print()
print("Rotated to left array:")
first=arr[0]
for i in range(0,n-1):
    arr[i]=arr[i+1]
arr[n-1]=first
for i in range(n):
    print(arr[i],end=" ")
# Out:
# Enter number of elements: 3
# Enter a value: 4
# Enter a value: 7
# Enter a value: 8
# Original array:
# 4 7 8
# Rotated to left array:
# 7 8 4

# %%
#code to rotate an array to right
n= int(input("Enter number of elements:"))
arr=[]
for i in range(n):
    val = int(input("Enter a value:"))
    arr.append(val)
print("Original array:")
for i in arr:
    print(i,end=" ")
print()
print("Rotated to left array:")
last=arr[n-1]
for i in range(n-1,0,-1):
    arr[i]=arr[i-1]
arr[0]=last
for i in range(n):
    print(arr[i],end=" ")
# Out:
# Enter number of elements: 4
# Enter a value: 1
# Enter a value: 2
# Enter a value: 3
# Enter a value: 4
# Original array:
# 1 2 3 4
# Rotated to left array:
# 4 1 2 3

# %%
#code to insert an element in an array wth repect to index value
n=int(input("enter number of elements"))
arr=[]
for i in range(n):
    val=int(input("enter a value"))
    arr.append(val)
print("Original array")
for i in arr:
    print(i,end=" ")
print()
pos=int(input("enter the position to delete"))
value=int(input("enter the value of position"))
arr.pop(pos)
print("latest array after deleting an element")
for i in arr:
    print(i,end=" ")
print()
pos=int(input("enter the position  to delete"))
value=int(input("enter the value of position"))
arr.pop(pos)
print("latest array after deleting an element")
for i in arr:
    print(i,end=" ")
print()
pos=int(input("enter the position  to modify"))
value=int(input("enter the value of position"))
arr[pos]=value
print("latest array after deleting an element")
for i in arr:
    print(i,end=" ")
